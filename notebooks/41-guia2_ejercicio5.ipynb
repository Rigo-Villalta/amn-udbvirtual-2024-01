# %% [markdown]
# 5- Se realiza un experimento para definir la relación entre el esfuerzo aplicado y el tiempo para que se
# fracture cierto tipo de acero inoxidable. A continuación se muestran los resultados, para distintos
# esfuerzos:
#
# | Esfuerzo aplicado kg/mm^2 | 5 | 10| 15 | 20 | 25 | 30 | 35 | 40 |
# |---|-----|-----|-----|-----|-----|-----|------|-----|
# | tiempo para la fractura(hr) | 40 | 30 | 25 | 40 | 18 | 20 | 22 | 15 |
#
# Aproxime el tiempo de fractura para un esfuerzo de 22 kg/mm2. Utilice 9 decimales
#
# Se debe mostrar:
#
# - Las funciones L construidas.
# - El polinomio de interpolación
# - El valor aproximado de la función

# %%
from math import e, cos

from metodos_interpolacion import lagrange
from utils import  imprimir_tabla

data_x = [5, 10, 15, 20, 25, 30, 35, 40]
data_y = [40, 30, 25, 40, 18, 20, 22, 15]


resultado = lagrange(data_x, data_y, 22, 9)
imprimir_tabla(resultado)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Concepto                        ┃ Dato                                                                          ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ La evaluación de 22 en L_0 es:  │ -0.00239616                                                                   │
# │                                 │                                                                               │
# │ El L_0 es:                      │ (x - 40)*(x - 35)*(x - 30)*(x - 25)*(x - 20)*(x - 15)*(x - 10)                │
# │                                 │ --------------------------------------------------------------------          │
# │                                 │                             -393750000.0                                      │
# ...
