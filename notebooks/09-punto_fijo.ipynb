# %%
# Prueba de algoritmo de punto fijo con ejemplo en clase

from metodos_numericos import punto_fijo
from utils import imprimir_tabla

def g_de_x(x):
    """
    Función g(x) proporcionada en la clase
    """
    return 20 / (x**2 + 2*x + 10)

resultado = punto_fijo(x0=1, g_de_x=g_de_x, resultado=[])
imprimir_tabla(resultado)
# Out:
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ # de iteración ┃ x0                ┃ x1                ┃ error             ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ 1              │ 1.000000000000000 │ 1.538461538461539 │ 0.538461538461539 │
# │ 2              │ 1.538461538461539 │ 1.295019157088122 │ 0.243442381373416 │
# │ 3              │ 1.295019157088122 │ 1.401825309448600 │ 0.106806152360478 │
# │ 4              │ 1.401825309448600 │ 1.354209390404292 │ 0.047615919044308 │
# │ 5              │ 1.354209390404292 │ 1.375298092487380 │ 0.021088702083087 │
# │ 6              │ 1.375298092487380 │ 1.365929788170655 │ 0.009368304316725 │
# │ 7              │ 1.365929788170655 │ 1.370086003401819 │ 0.004156215231164 │
# │ 8              │ 1.370086003401819 │ 1.368241023612835 │ 0.001844979788984 │
# │ 9              │ 1.368241023612835 │ 1.369059812007482 │ 0.000818788394647 │
# ...
