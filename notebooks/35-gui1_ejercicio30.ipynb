# %%
from math import e, sin

from metodos_numericos import biseccion
from utils import imprimir_tabla

def f(x):
    return ((-32.17) / (2 * x**2)) * (((e**(x) - e**(-x)) / 2) - sin(x)  )

resultado = biseccion(-1, 0.5, f, 10E-12, 1, [])
imprimir_tabla(resultado)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 9
#       6 def f(x):
#       7     return ((-32.17) / (2 * x**2)) * (((e**(x) - e**(-x)) / 2) - sin(x)  )
# ----> 9 resultado = biseccion(-1, 0.5, f, 10E-12, 1, [])
#      10 imprimir_tabla(resultado)
#
# File ~/udb/ciclo-2024-01/amn/amn-udbvirtual-2024-01/notebooks/metodos_numericos.py:47, in biseccion(a, b, func, tolerancia, iteracion, resultado)
#      43 elif func(b) * func(c) < 0:
#      44     resultado.append(
#      45         [str(iteracion), f"{a:,.15f}", f"{b:,.15f}", f"{c:,.15f}", f"{error:,.15f}"]
#      46     )
# ---> 47     return biseccion(b, c, func, tolerancia, iteracion + 1, resultado)
#      48 else:
#      49     raise ValueError("El valor procesado no es correcto")
#
# ...
